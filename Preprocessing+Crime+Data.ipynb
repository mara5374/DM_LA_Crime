# %%
import pandas as pd
import numpy as np
import datetime as dt

data = pd.read_csv("Crime_Data_from_2010_to_Present.csv",dtype='O')
data['Date Reported'] = pd.to_datetime(data['Date Reported'],yearfirst=True)
data['Date Occurred'] = pd.to_datetime(data['Date Occurred'],yearfirst=True)
data['Time Occurred'] = data["Time Occurred"].astype('int64')

#all numeric values are used to specify codes/IDs; all data is qualitative
#normalize all values to object except for datetime columns
#deal with NaN values; data.dropna(axis=0) to ignore for now
#do some binning and/or clustering with datetime objects?
#what about location coordinates?
# Out:
# DR Number                         object
# Date Reported             datetime64[ns]
# Date Occurred             datetime64[ns]
# Time Occurred                      int64
# Area ID                           object
# Area Name                         object
# Reporting District                object
# Crime Code                        object
# Crime Code Description            object
# MO Codes                          object
# Victim Age                        object
# Victim Sex                        object
# Victim Descent                    object
# Premise Code                      object
# Premise Description               object
# Weapon Used Code                  object
# Weapon Description                object
# Status Code                       object
# Status Description                object
# Crime Code 1                      object
# Crime Code 2                      object
# Crime Code 3                      object
# Crime Code 4                      object
# ...

# %%
data.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred Area ID    Area Name  \
# 0  001208575    2013-03-14    2013-03-11           1800      12  77th Street
# 1  102005556    2010-01-25    2010-01-22           2300      20      Olympic
# 2       0418    2013-03-19    2013-03-18           2030      18    Southeast
# 3  101822289    2010-11-11    2010-11-10           1800      18    Southeast
# 4  042104479    2014-01-11    2014-01-04           2300      21      Topanga
#
#   Reporting District Crime Code                    Crime Code Description  \
# 0               1241        626         INTIMATE PARTNER - SIMPLE ASSAULT
# 1               2071        510                          VEHICLE - STOLEN
# 2               1823        510                          VEHICLE - STOLEN
# 3               1803        510                          VEHICLE - STOLEN
# 4               2133        745  VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
#               MO Codes          ...           \
# ...
